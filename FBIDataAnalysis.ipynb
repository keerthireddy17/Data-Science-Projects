# %% [markdown]
# <a href="https://colab.research.google.com/github/keerthireddy17/Pyspark-Project/blob/main/FBIDataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
from google.colab import drive
drive.mount('/content/fbi.xlsx')
# Out:
# Drive already mounted at /content/fbi.xlsx; to attempt to forcibly remount, call drive.mount("/content/fbi.xlsx", force_remount=True).

# %%
# pd.read_excel()

fbi = pd.read_excel('/fbi.xlsx')
fbi.head()
# Out:
#                                              Table 2 Unnamed: 1   Unnamed: 2  \
# 0                        Crime in the United States1        NaN          NaN
# 1  by Region, Geographic Division, and State, 201...        NaN          NaN
# 2                                               Area       Year  Population2
# 3                                                NaN        NaN          NaN
# 4                      United States Total6, 7, 8, 9       2015    320896618
#
#        Unnamed: 3          Unnamed: 4  \
# 0             NaN
# 1             NaN                 NaN
# 2  Violent crime3                 NaN
# 3                  Rate per \n100,000
# 4         1234183               384.6
#
#                                  Unnamed: 5          Unnamed: 6  \
# 0
# 1                                       NaN
# 2  Murder and \nnonnegligent \nmanslaughter                 NaN
# 3                                            Rate per \n100,000
# 4                                     15883                 4.9
#
#                     Unnamed: 7          Unnamed: 8  \
# 0
# 1                          NaN                 NaN
# 2  Rape\n(revised definition)4                 NaN
# 3                               Rate per \n100,000
# 4                       126134                39.3
#
#                    Unnamed: 9         Unnamed: 10 Unnamed: 11  \
# 0                                                         NaN
# 1                         NaN                 NaN         NaN
# 2  Rape\n(legacy definition)5                 NaN     Robbery
# 3                              Rate per \n100,000
# 4                       91261                28.4      328109
#
#           Unnamed: 12         Unnamed: 13         Unnamed: 14     Unnamed: 15  \
# 0                 NaN                 NaN                 NaN             NaN
# 1                 NaN                 NaN                 NaN             NaN
# 2                 NaN  Aggravated assault                 NaN  Property crime
# 3  Rate per \n100,000                      Rate per \n100,000
# 4               102.2              764057               238.1         8024115
#
#           Unnamed: 16 Unnamed: 17         Unnamed: 18    Unnamed: 19  \
# 0                 NaN         NaN                 NaN            NaN
# 1                 NaN         NaN                 NaN            NaN
# 2                 NaN    Burglary                 NaN  Larceny-theft
# 3  Rate per \n100,000              Rate per \n100,000
# 4              2500.5     1587564               494.7        5723488
#
#           Unnamed: 20          Unnamed: 21         Unnamed: 22
# 0                 NaN                  NaN                 NaN
# 1                 NaN                  NaN                 NaN
# 2                 NaN  Motor vehicle theft                 NaN
# 3  Rate per \n100,000                       Rate per \n100,000
# 4              1783.6               713063               222.2

# %%
pd.set_option('display.max.columns', None)
fbi.head()
# Out:
#                                              Table 2 Unnamed: 1   Unnamed: 2  \
# 0                        Crime in the United States1        NaN          NaN
# 1  by Region, Geographic Division, and State, 201...        NaN          NaN
# 2                                               Area       Year  Population2
# 3                                                NaN        NaN          NaN
# 4                      United States Total6, 7, 8, 9       2015    320896618
#
#        Unnamed: 3          Unnamed: 4  \
# 0             NaN
# 1             NaN                 NaN
# 2  Violent crime3                 NaN
# 3                  Rate per \n100,000
# 4         1234183               384.6
#
#                                  Unnamed: 5          Unnamed: 6  \
# 0
# 1                                       NaN
# 2  Murder and \nnonnegligent \nmanslaughter                 NaN
# 3                                            Rate per \n100,000
# 4                                     15883                 4.9
#
#                     Unnamed: 7          Unnamed: 8  \
# 0
# 1                          NaN                 NaN
# 2  Rape\n(revised definition)4                 NaN
# 3                               Rate per \n100,000
# 4                       126134                39.3
#
#                    Unnamed: 9         Unnamed: 10 Unnamed: 11  \
# 0                                                         NaN
# 1                         NaN                 NaN         NaN
# 2  Rape\n(legacy definition)5                 NaN     Robbery
# 3                              Rate per \n100,000
# 4                       91261                28.4      328109
#
#           Unnamed: 12         Unnamed: 13         Unnamed: 14     Unnamed: 15  \
# 0                 NaN                 NaN                 NaN             NaN
# 1                 NaN                 NaN                 NaN             NaN
# 2                 NaN  Aggravated assault                 NaN  Property crime
# 3  Rate per \n100,000                      Rate per \n100,000
# 4               102.2              764057               238.1         8024115
#
#           Unnamed: 16 Unnamed: 17         Unnamed: 18    Unnamed: 19  \
# 0                 NaN         NaN                 NaN            NaN
# 1                 NaN         NaN                 NaN            NaN
# 2                 NaN    Burglary                 NaN  Larceny-theft
# 3  Rate per \n100,000              Rate per \n100,000
# 4              2500.5     1587564               494.7        5723488
#
#           Unnamed: 20          Unnamed: 21         Unnamed: 22
# 0                 NaN                  NaN                 NaN
# 1                 NaN                  NaN                 NaN
# 2                 NaN  Motor vehicle theft                 NaN
# 3  Rate per \n100,000                       Rate per \n100,000
# 4              1783.6               713063               222.2

# %%
# The first 2 rows and the last 8 rows are trash, clean it!
fbi.drop(fbi.index[0:2], inplace=True)
fbi.drop(fbi.index[-11:], inplace=True)
fbi.reset_index(inplace=True, drop=True)
fbi.head()
# Out:
#                          Table 2      Unnamed: 1   Unnamed: 2      Unnamed: 3  \
# 0                           Area            Year  Population2  Violent crime3
# 1                            NaN             NaN          NaN
# 2  United States Total6, 7, 8, 9            2015    320896618         1234183
# 3                            NaN            2016    323127513         1283058
# 4                            NaN  Percent change          NaN               4
#
#            Unnamed: 4                                Unnamed: 5  \
# 0                 NaN  Murder and \nnonnegligent \nmanslaughter
# 1  Rate per \n100,000
# 2               384.6                                     15883
# 3               397.1                                     17250
# 4                 3.2                                       8.6
#
#            Unnamed: 6                   Unnamed: 7          Unnamed: 8  \
# 0                 NaN  Rape\n(revised definition)4                 NaN
# 1  Rate per \n100,000                               Rate per \n100,000
# 2                 4.9                       126134                39.3
# 3                 5.3                       130603                40.4
# 4                 7.9                          3.5                 2.8
#
#                    Unnamed: 9         Unnamed: 10 Unnamed: 11  \
# 0  Rape\n(legacy definition)5                 NaN     Robbery
# 1                              Rate per \n100,000
# 2                       91261                28.4      328109
# 3                       95730                29.6      332198
# 4                         4.9                 4.2         1.2
#
#           Unnamed: 12         Unnamed: 13         Unnamed: 14     Unnamed: 15  \
# 0                 NaN  Aggravated assault                 NaN  Property crime
# 1  Rate per \n100,000                      Rate per \n100,000
# 2               102.2              764057               238.1         8024115
# 3               102.8              803007               248.5         7919035
# 4                 0.5                 5.1                 4.4            -1.3
#
#           Unnamed: 16 Unnamed: 17         Unnamed: 18    Unnamed: 19  \
# 0                 NaN    Burglary                 NaN  Larceny-theft
# 1  Rate per \n100,000              Rate per \n100,000
# 2              2500.5     1587564               494.7        5723488
# 3              2450.7     1515096               468.9        5638455
# 4                  -2        -4.6                -5.2           -1.5
#
#           Unnamed: 20          Unnamed: 21         Unnamed: 22
# 0                 NaN  Motor vehicle theft                 NaN
# 1  Rate per \n100,000                       Rate per \n100,000
# 2              1783.6               713063               222.2
# 3                1745               765484               236.9
# 4                -2.2                  7.4                 6.6

# %%
fbi.iloc[0]
# Out:
# Table 2                                            Area
# Unnamed: 1                                         Year
# Unnamed: 2                                  Population2
# Unnamed: 3                               Violent crime3
# Unnamed: 4                                          NaN
# Unnamed: 5     Murder and \nnonnegligent \nmanslaughter
# Unnamed: 6                                          NaN
# Unnamed: 7                  Rape\n(revised definition)4
# Unnamed: 8                                          NaN
# Unnamed: 9                   Rape\n(legacy definition)5
# Unnamed: 10                                         NaN
# Unnamed: 11                                     Robbery
# Unnamed: 12                                         NaN
# Unnamed: 13                          Aggravated assault
# Unnamed: 14                                         NaN
# Unnamed: 15                              Property crime
# Unnamed: 16                                         NaN
# Unnamed: 17                                    Burglary
# Unnamed: 18                                         NaN
# Unnamed: 19                               Larceny-theft
# Unnamed: 20                                         NaN
# Unnamed: 21                         Motor vehicle theft
# Unnamed: 22                                         NaN
# Name: 0, dtype: object

# %%
cols = []

for i in range(0, 4):
    cols.append(fbi.iloc[0][i])

for i in range(4,23):
    if i%2 == 1:
        cols.append(fbi.iloc[0][i])

cols
# Out:
# ['Area',
#  'Year',
#  'Population2',
#  'Violent crime3',
#  'Murder and \nnonnegligent \nmanslaughter',
#  'Rape\n(revised definition)4',
#  'Rape\n(legacy definition)5',
#  'Robbery',
#  'Aggravated assault',
#  'Property crime',
#  'Burglary',
#  'Larceny-theft',
#  'Motor vehicle theft']

# %%
# Update column names

fbi.columns = fbi.iloc[0]
fbi.drop(fbi.index[0:2], inplace=True)
fbi.reset_index(inplace=True, drop=True)
fbi.head()
# Out:
# 0                           Area            Year Population2 Violent crime3  \
# 0  United States Total6, 7, 8, 9            2015   320896618        1234183
# 1                            NaN            2016   323127513        1283058
# 2                            NaN  Percent change         NaN              4
# 3                     Northeast6            2015    56184737         180474
# 4                            NaN            2016    56209510         178244
#
# 0    NaN Murder and \nnonnegligent \nmanslaughter  NaN  \
# 0  384.6                                    15883  4.9
# 1  397.1                                    17250  5.3
# 2    3.2                                      8.6  7.9
# 3  321.2                                     1967  3.5
# 4  317.1                                     1955  3.5
#
# 0 Rape\n(revised definition)4   NaN Rape\n(legacy definition)5   NaN Robbery  \
# 0                      126134  39.3                      91261  28.4  328109
# 1                      130603  40.4                      95730  29.6  332198
# 2                         3.5   2.8                        4.9   4.2     1.2
# 3                       16415  29.2                      11912  21.2   56202
# 4                       16651  29.6                      12219  21.7   53033
#
# 0    NaN Aggravated assault    NaN Property crime     NaN Burglary    NaN  \
# 0  102.2             764057  238.1        8024115  2500.5  1587564  494.7
# 1  102.8             803007  248.5        7919035  2450.7  1515096  468.9
# 2    0.5                5.1    4.4           -1.3      -2     -4.6   -5.2
# 3    100             105890  188.5         951940  1694.3   157910  281.1
# 4   94.3             106605  189.7         909897  1618.8   142720  253.9
#
# 0 Larceny-theft     NaN Motor vehicle theft    NaN
# 0       5723488  1783.6              713063  222.2
# 1       5638455    1745              765484  236.9
# 2          -1.5    -2.2                 7.4    6.6
# 3        737087  1311.9               56943  101.3
# 4        709721  1262.6               57456  102.2

# %%
cols = fbi.columns[fbi.columns.notnull()]
fbi = fbi[cols].copy()
fbi.head()
# Out:
# 0                           Area            Year Population2 Violent crime3  \
# 0  United States Total6, 7, 8, 9            2015   320896618        1234183
# 1                            NaN            2016   323127513        1283058
# 2                            NaN  Percent change         NaN              4
# 3                     Northeast6            2015    56184737         180474
# 4                            NaN            2016    56209510         178244
#
# 0 Murder and \nnonnegligent \nmanslaughter Rape\n(revised definition)4  \
# 0                                    15883                      126134
# 1                                    17250                      130603
# 2                                      8.6                         3.5
# 3                                     1967                       16415
# 4                                     1955                       16651
#
# 0 Rape\n(legacy definition)5 Robbery Aggravated assault Property crime  \
# 0                      91261  328109             764057        8024115
# 1                      95730  332198             803007        7919035
# 2                        4.9     1.2                5.1           -1.3
# 3                      11912   56202             105890         951940
# 4                      12219   53033             106605         909897
#
# 0 Burglary Larceny-theft Motor vehicle theft
# 0  1587564       5723488              713063
# 1  1515096       5638455              765484
# 2     -4.6          -1.5                 7.4
# 3   157910        737087               56943
# 4   142720        709721               57456

# %%
# Remove Percent Change rows

for index, row in fbi.iterrows():
    if row['Year'] == 'Percent change':
        fbi.drop(index, inplace=True)
fbi.reset_index(inplace=True, drop=True)
fbi.head()
# Out:
# 0                           Area  Year Population2 Violent crime3  \
# 0  United States Total6, 7, 8, 9  2015   320896618        1234183
# 1                            NaN  2016   323127513        1283058
# 2                     Northeast6  2015    56184737         180474
# 3                            NaN  2016    56209510         178244
# 4                   New England6  2015    14710229          42121
#
# 0 Murder and \nnonnegligent \nmanslaughter Rape\n(revised definition)4  \
# 0                                    15883                      126134
# 1                                    17250                      130603
# 2                                     1967                       16415
# 3                                     1955                       16651
# 4                                      326                        4602
#
# 0 Rape\n(legacy definition)5 Robbery Aggravated assault Property crime  \
# 0                      91261  328109             764057        8024115
# 1                      95730  332198             803007        7919035
# 2                      11912   56202             105890         951940
# 3                      12219   53033             106605         909897
# 4                       3374    9629              27564         257073
#
# 0 Burglary Larceny-theft Motor vehicle theft
# 0  1587564       5723488              713063
# 1  1515096       5638455              765484
# 2   157910        737087               56943
# 3   142720        709721               57456
# 4    46260        193051               17762

# %%
# The first 2 rows are not necessary, clean it!

fbi.drop(fbi.index[0:2], inplace=True)
fbi.reset_index(inplace=True, drop=True)
fbi.head()
# Out:
# 0              Area  Year Population2 Violent crime3  \
# 0        Northeast6  2015    56184737         180474
# 1               NaN  2016    56209510         178244
# 2      New England6  2015    14710229          42121
# 3               NaN  2016    14735525          41598
# 4       Connecticut  2015     3584730           7938
#
# 0 Murder and \nnonnegligent \nmanslaughter Rape\n(revised definition)4  \
# 0                                     1967                       16415
# 1                                     1955                       16651
# 2                                      326                        4602
# 3                                      292                        4505
# 4                                      116                         798
#
# 0 Rape\n(legacy definition)5 Robbery Aggravated assault Property crime  \
# 0                      11912   56202             105890         951940
# 1                      12219   53033             106605         909897
# 2                       3374    9629              27564         257073
# 3                       3328    9407              27394         243769
# 4                        585    2925               4099          65610
#
# 0 Burglary Larceny-theft Motor vehicle theft
# 0   157910        737087               56943
# 1   142720        709721               57456
# 2    46260        193051               17762
# 3    42095        182985               18689
# 4    10286         48898                6426

# %%
# Fill the blanks in Area column

for i in range(fbi.shape[0]):
    if str(fbi['Area'][i]) == 'nan':
        fbi['Area'][i] = fbi['Area'][i-1]

fbi.head(20)
# Out:
# 0                 Area  Year Population2 Violent crime3  \
# 0           Northeast6  2015    56184737         180474
# 1           Northeast6  2016    56209510         178244
# 2         New England6  2015    14710229          42121
# 3         New England6  2016    14735525          41598
# 4          Connecticut  2015     3584730           7938
# 5          Connecticut  2016     3576452           8123
# 6                Maine  2015     1329453           1726
# 7                Maine  2016     1331479           1648
# 8        Massachusetts  2015     6784240          26453
# 9        Massachusetts  2016     6811779          25677
# 10       New Hampshire  2015     1330111           2692
# 11       New Hampshire  2016     1334795           2637
# 12       Rhode Island6  2015     1055607           2565
# 13       Rhode Island6  2016     1056426           2524
# 14             Vermont  2015      626088            747
# 15             Vermont  2016      624594            989
# 16    Middle Atlantic6  2015    41474508         138353
# 17    Middle Atlantic6  2016    41473985         136646
# 18          New Jersey  2015     8935421          22879
# 19          New Jersey  2016     8944469          21914
#
# 0  Murder and \nnonnegligent \nmanslaughter Rape\n(revised definition)4  \
# 0                                      1967                       16415
# 1                                      1955                       16651
# 2                                       326                        4602
# 3                                       292                        4505
# 4                                       116                         798
# 5                                        78                         763
# 6                                        23                         461
# 7                                        20                         412
# 8                                       131                        2082
# 9                                       134                        2128
# 10                                       15                         644
# 11                                       17                         582
# 12                                       31                         467
# 13                                       29                         442
# 14                                       10                         150
# 15                                       14                         178
# 16                                     1641                       11813
# 17                                     1663                       12146
# 18                                      363                        1373
# 19                                      372                        1453
#
# 0  Rape\n(legacy definition)5 Robbery Aggravated assault Property crime  \
# 0                       11912   56202             105890         951940
# 1                       12219   53033             106605         909897
# 2                        3374    9629              27564         257073
# 3                        3328    9407              27394         243769
# 4                         585    2925               4099          65610
# 5                         561    2703               4579          64664
# 6                         337     311                931          24361
# 7                         300     266                950          21912
# 8                        1538    5266              18974         114547
# 9                        1592    5365              18050         106339
# 10                        468     475               1558          23453
# 11                        423     427               1611          20194
# 12                        342     547               1520          20038
# 13                        328     540               1513          20058
# 14                        104     105                482           9064
# 15                        124     106                691          10602
# 16                       8538   46573              78326         694867
# 17                       8891   43626              79211         666128
# 18                       1019    9729              11414         145701
# 19                       1089    8984              11105         138152
#
# 0  Burglary Larceny-theft Motor vehicle theft
# 0    157910        737087               56943
# 1    142720        709721               57456
# 2     46260        193051               17762
# 3     42095        182985               18689
# 4     10286         48898                6426
# 5     10045         47512                7107
# 6      4694         18853                 814
# 7      4003         17134                 775
# 8     21826         84676                8045
# 9     19193         79088                8058
# 10     3482         19076                 895
# 11     2963         16360                 871
# 12     3938         14714                1386
# 13     3788         14674                1596
# 14     2034          6834                 196
# 15     2103          8217                 282
# 16   111650        544036               39181
# 17   100625        526736               38767
# 18    27960        105963               11778
# 19    25284        101540               11328

# %%
# Look at this here! If any row has '5' space, then the row must be State!

for i in fbi['Area'].unique():
    print(i)
# Out:
# Northeast6
# New England6
#      Connecticut
#      Maine
#      Massachusetts
#      New Hampshire
#      Rhode Island6
#      Vermont
# Middle Atlantic6
#      New Jersey
#      New York6
#      Pennsylvania
# Midwest6
# East North Central6
#      Illinois
#      Indiana6
#      Michigan
#      Ohio6
#      Wisconsin6
# West North Central6
#      Iowa
#      Kansas
#      Minnesota
#      Missouri
#      Nebraska6
#      North Dakota
#      South Dakota6
# South6, 7 ,8
# South Atlantic6, 7, 8
#      Delaware
#      District of Columbia7
#      Florida
#      Georgia8
#      Maryland
#      North Carolina6
#      South Carolina
#      Virginia
#      West Virginia
# East South Central6
#      Alabama
#      Kentucky
#      Mississippi6
#      Tennessee
# West South Central6
#      Arkansas
#      Louisiana
#      Oklahoma6
#      Texas
# West6
# Mountain6
#      Arizona
#      Colorado
#      Idaho
#      Montana
#      Nevada
#      New Mexico6
#      Utah
#      Wyoming
# Pacific6
#      Alaska
#      California
#      Hawaii
#      Oregon6
#      Washington6
# Puerto Rico9

# %%
#  Clear unnecessary numbers of States

for i in range(fbi.shape[0]):
    # Specific solution for South and South Atlantic
    if fbi['Area'][i] == 'South6, 7 ,8':
        fbi['Area'][i] = 'South'
    if fbi['Area'][i] == 'South Atlantic6, 7,8':
        fbi['Area'][i] = 'South Atlantic'
    for j in fbi['Area'][i]:
        try:
            a = int(j)
        except:
            a = None

        if isinstance(a, int):
            fbi['Area'][i] = fbi['Area'][i].replace(str(a)+', ', '')
            fbi['Area'][i] = fbi['Area'][i].replace(str(a), '')

fbi.head(10)
# Out:
# 0                Area  Year Population2 Violent crime3  \
# 0           Northeast  2015    56184737         180474
# 1           Northeast  2016    56209510         178244
# 2         New England  2015    14710229          42121
# 3         New England  2016    14735525          41598
# 4         Connecticut  2015     3584730           7938
# 5         Connecticut  2016     3576452           8123
# 6               Maine  2015     1329453           1726
# 7               Maine  2016     1331479           1648
# 8       Massachusetts  2015     6784240          26453
# 9       Massachusetts  2016     6811779          25677
#
# 0 Murder and \nnonnegligent \nmanslaughter Rape\n(revised definition)4  \
# 0                                     1967                       16415
# 1                                     1955                       16651
# 2                                      326                        4602
# 3                                      292                        4505
# 4                                      116                         798
# 5                                       78                         763
# 6                                       23                         461
# 7                                       20                         412
# 8                                      131                        2082
# 9                                      134                        2128
#
# 0 Rape\n(legacy definition)5 Robbery Aggravated assault Property crime  \
# 0                      11912   56202             105890         951940
# 1                      12219   53033             106605         909897
# 2                       3374    9629              27564         257073
# 3                       3328    9407              27394         243769
# 4                        585    2925               4099          65610
# 5                        561    2703               4579          64664
# 6                        337     311                931          24361
# 7                        300     266                950          21912
# 8                       1538    5266              18974         114547
# 9                       1592    5365              18050         106339
#
# 0 Burglary Larceny-theft Motor vehicle theft
# 0   157910        737087               56943
# 1   142720        709721               57456
# 2    46260        193051               17762
# 3    42095        182985               18689
# 4    10286         48898                6426
# 5    10045         47512                7107
# 6     4694         18853                 814
# 7     4003         17134                 775
# 8    21826         84676                8045
# 9    19193         79088                8058

# %%
# Clear unnecessary numbers of Column names

cols = fbi.columns
new_cols = []

for i in cols:
    for j in i:
        try:
            a = int(j)

        except:
            a = None

    if isinstance(a, int):
        b = i.replace(j, '')

    else:
        b = i

    new_cols.append(b)

fbi.columns = new_cols
fbi.head()
# Out:
#                Area  Year Population Violent crime  \
# 0         Northeast  2015   56184737        180474
# 1         Northeast  2016   56209510        178244
# 2       New England  2015   14710229         42121
# 3       New England  2016   14735525         41598
# 4       Connecticut  2015    3584730          7938
#
#   Murder and \nnonnegligent \nmanslaughter Rape\n(revised definition)  \
# 0                                     1967                      16415
# 1                                     1955                      16651
# 2                                      326                       4602
# 3                                      292                       4505
# 4                                      116                        798
#
#   Rape\n(legacy definition) Robbery Aggravated assault Property crime  \
# 0                     11912   56202             105890         951940
# 1                     12219   53033             106605         909897
# 2                      3374    9629              27564         257073
# 3                      3328    9407              27394         243769
# 4                       585    2925               4099          65610
#
#   Burglary Larceny-theft Motor vehicle theft
# 0   157910        737087               56943
# 1   142720        709721               57456
# 2    46260        193051               17762
# 3    42095        182985               18689
# 4    10286         48898                6426

# %%
# Split data by regions

north_east = fbi.loc[fbi['Area']=='Northeast'].index.values.astype(int)[0]
mid_west = fbi.loc[fbi['Area']=='Midwest'].index.values.astype(int)[0]
south = fbi.loc[fbi['Area']=='South'].index.values.astype(int)[0]
west = fbi.loc[fbi['Area']=='West'].index.values.astype(int)[0]

fbi_north = fbi[north_east:mid_west].copy()
fbi_mid = fbi[mid_west:south].copy()
fbi_south = fbi[south:west].copy()
fbi_west = fbi[west:].copy()

# %%
# Add 'Region' columns

fbi_north['Region'] = 'Northeast'
fbi_mid['Region'] = 'Midwest'
fbi_south['Region'] = 'South'
fbi_west['Region'] = 'West'

# %%
# Take the Region data to another dataframe. Maybe one day it will be needed.

fbi_region = pd.concat([fbi_north[0:2], fbi_mid[0:2], fbi_south[0:2], fbi_west[0:2]])
fbi_region.reset_index(inplace=True, drop=True)
fbi_region
# Out:
#         Area  Year Population Violent crime  \
# 0  Northeast  2015   56184737        180474
# 1  Northeast  2016   56209510        178244
# 2    Midwest  2015   67838387        242893
# 3    Midwest  2016   67941429        257109
# 4      South  2015  121039206        509043
# 5      South  2016  122319574        526999
# 6       West  2015   75834288        301773
# 7       West  2016   76657000        320706
#
#   Murder and \nnonnegligent \nmanslaughter Rape\n(revised definition)  \
# 0                                     1967                      16415
# 1                                     1955                      16651
# 2                                     3422                      30827
# 3                                     3885                      31408
# 4                                     7300                      47277
# 5                                     7961                      49246
# 6                                     3194                      31615
# 7                                     3449                      33298
#
#   Rape\n(legacy definition) Robbery Aggravated assault Property crime  \
# 0                     11912   56202             105890         951940
# 1                     12219   53033             106605         909897
# 2                     22395   62201             146443        1555516
# 3                     23080   64022             157794        1544531
# 4                     33960  127149             327317        3393611
# 5                     35869  128842             340950        3343799
# 6                     22994   82557             184407        2123048
# 7                     24562   86301             197658        2120808
#
#   Burglary Larceny-theft Motor vehicle theft     Region
# 0   157910        737087               56943  Northeast
# 1   142720        709721               57456  Northeast
# 2   307853       1125935              121728    Midwest
# 3   300359       1112596              131576    Midwest
# 4   719098       2422679              251834      South
# 5   684968       2391288              267543      South
# 6   402703       1437787              282558       West
# 7   387049       1424850              308909       West

# %%
# Clear first 2 rows of split data
fbi_north.drop(fbi_north.index[0:2], inplace=True)
fbi_north.reset_index(inplace=True, drop=True)
fbi_mid.drop(fbi_mid.index[0:2], inplace=True)
fbi_mid.reset_index(inplace=True, drop=True)
fbi_south.drop(fbi_south.index[0:2], inplace=True)
fbi_south.reset_index(inplace=True, drop=True)
fbi_west.drop(fbi_west.index[0:2], inplace=True)
fbi_west.reset_index(inplace=True, drop=True)

# %%
fbi_north['Geographic_Division'] = None
for i in range(fbi_north.shape[0]):
    if fbi_north['Area'][i][0:5] != '     ':
        fbi_north['Geographic_Division'][i] = fbi_north['Area'][i]

    else:
        fbi_north['Geographic_Division'][i] = fbi_north['Geographic_Division'][i-1]

# ----------------------------------------------------------------------------------

fbi_mid['Geographic_Division'] = None
for i in range(fbi_mid.shape[0]):
    if fbi_mid['Area'][i][0:5] != '     ':
        fbi_mid['Geographic_Division'][i] = fbi_mid['Area'][i]

    else:
        fbi_mid['Geographic_Division'][i] = fbi_mid['Geographic_Division'][i-1]

# -----------
fbi_south['Geographic_Division'] = None
for i in range(fbi_south.shape[0]):
    if fbi_south['Area'][i][0:5] != '     ':
        fbi_south['Geographic_Division'][i] = fbi_south['Area'][i]

    else:
        fbi_south['Geographic_Division'][i] = fbi_south['Geographic_Division'][i-1]

# ----------------------------------------------------------------------------------

fbi_west['Geographic_Division'] = None
for i in range(fbi_west.shape[0]):
    if fbi_west['Area'][i][0:5] != '     ':
        fbi_west['Geographic_Division'][i] = fbi_west['Area'][i]

    else:
        fbi_west['Geographic_Division'][i] = fbi_west['Geographic_Division'][i-1]

# %%
# Sample

fbi_south.head()
# Out:
#                         Area  Year Population Violent crime  \
# 0            South Atlantic   2015   63192408        256283
# 1            South Atlantic   2016   63923309        258672
# 2                   Delaware  2015     944076          4760
# 3                   Delaware  2016     952065          4844
# 4       District of Columbia  2015     670377          8538
#
#   Murder and \nnonnegligent \nmanslaughter Rape\n(revised definition)  \
# 0                                     3824                      21620
# 1                                     4077                      22333
# 2                                       62                        361
# 3                                       56                        308
# 4                                      162                        494
#
#   Rape\n(legacy definition) Robbery Aggravated assault Property crime  \
# 0                     15433   66792             164047        1721061
# 1                     16174   66402             165860        1692669
# 2                       257    1240               3097          25545
# 3                       221    1359               3121          26334
# 4                       365    3746               4136          31444
#
#   Burglary Larceny-theft Motor vehicle theft Region Geographic_Division
# 0   352328       1246078              122655  South     South Atlantic
# 1   330122       1234761              127786  South     South Atlantic
# 2     4797         19555                1193  South     South Atlantic
# 3     5023         19791                1520  South     South Atlantic
# 4     2971         25208                3265  South     South Atlantic

# %%
# Merge the split data

fbi = pd.concat([fbi_north, fbi_mid, fbi_south, fbi_west], ignore_index=True)

fbi['State'] = fbi['Area'].copy()
fbi.drop('Area', axis=1, inplace=True)
fbi.head()
# Out:
#    Year Population Violent crime Murder and \nnonnegligent \nmanslaughter  \
# 0  2015   14710229         42121                                      326
# 1  2016   14735525         41598                                      292
# 2  2015    3584730          7938                                      116
# 3  2016    3576452          8123                                       78
# 4  2015    1329453          1726                                       23
#
#   Rape\n(revised definition) Rape\n(legacy definition) Robbery  \
# 0                       4602                      3374    9629
# 1                       4505                      3328    9407
# 2                        798                       585    2925
# 3                        763                       561    2703
# 4                        461                       337     311
#
#   Aggravated assault Property crime Burglary Larceny-theft  \
# 0              27564         257073    46260        193051
# 1              27394         243769    42095        182985
# 2               4099          65610    10286         48898
# 3               4579          64664    10045         47512
# 4                931          24361     4694         18853
#
#   Motor vehicle theft     Region Geographic_Division             State
# 0               17762  Northeast         New England       New England
# 1               18689  Northeast         New England       New England
# 2                6426  Northeast         New England       Connecticut
# 3                7107  Northeast         New England       Connecticut
# 4                 814  Northeast         New England             Maine

# %%
cols = ['Region', 'Geographic_Division', 'State']
cols += list(fbi.columns)
del cols[-3:]
cols
fbi = fbi[cols]
fbi.head()
# Out:
#       Region Geographic_Division             State  Year Population  \
# 0  Northeast         New England       New England  2015   14710229
# 1  Northeast         New England       New England  2016   14735525
# 2  Northeast         New England       Connecticut  2015    3584730
# 3  Northeast         New England       Connecticut  2016    3576452
# 4  Northeast         New England             Maine  2015    1329453
#
#   Violent crime Murder and \nnonnegligent \nmanslaughter  \
# 0         42121                                      326
# 1         41598                                      292
# 2          7938                                      116
# 3          8123                                       78
# 4          1726                                       23
#
#   Rape\n(revised definition) Rape\n(legacy definition) Robbery  \
# 0                       4602                      3374    9629
# 1                       4505                      3328    9407
# 2                        798                       585    2925
# 3                        763                       561    2703
# 4                        461                       337     311
#
#   Aggravated assault Property crime Burglary Larceny-theft Motor vehicle theft
# 0              27564         257073    46260        193051               17762
# 1              27394         243769    42095        182985               18689
# 2               4099          65610    10286         48898                6426
# 3               4579          64664    10045         47512                7107
# 4                931          24361     4694         18853                 814

# %%
for i in range(fbi.shape[0]):
    if fbi['State'][i][0:5] == "     ":
        fbi['State'][i] = fbi['State'][i].replace("     ", "")

# %%
# Take the Division data to another dataframe. Maybe one day it will be needed like Region data.

fbi_division = fbi.loc[fbi['Geographic_Division'] == fbi['State']]

# %%
# Drop divisions from main dataframe

fbi.drop(fbi.loc[fbi['Geographic_Division'] == fbi['State']].index, inplace=True)
fbi.reset_index(inplace=True, drop=True)

# %%
# Update column names again

cols = list(fbi.columns)

for i in range(len(cols)):
    cols[i] = cols[i].replace("\n", "")

fbi.columns = cols

# %%
fbi.head(100)
# Out:
#        Region Geographic_Division          State  Year Population  \
# 0   Northeast         New England    Connecticut  2015    3584730
# 1   Northeast         New England    Connecticut  2016    3576452
# 2   Northeast         New England          Maine  2015    1329453
# 3   Northeast         New England          Maine  2016    1331479
# 4   Northeast         New England  Massachusetts  2015    6784240
# ..        ...                 ...            ...   ...        ...
# 95       West             Pacific     California  2016   39250017
# 96       West             Pacific         Hawaii  2015    1425157
# 97       West             Pacific         Hawaii  2016    1428557
# 98       West             Pacific         Oregon  2015    4024634
# 99       West             Pacific         Oregon  2016    4093465
#
#    Violent crime Murder and nonnegligent manslaughter  \
# 0           7938                                  116
# 1           8123                                   78
# 2           1726                                   23
# 3           1648                                   20
# 4          26453                                  131
# ..           ...                                  ...
# 95        174796                                 1930
# 96          3530                                   29
# 97          4417                                   35
# 98         10680                                  110
# 99         10830                                  113
#
#    Rape(revised definition) Rape(legacy definition) Robbery  \
# 0                       798                     585    2925
# 1                       763                     561    2703
# 2                       461                     337     311
# 3                       412                     300     266
# 4                      2082                    1538    5266
# ..                      ...                     ...     ...
# 95                    13702                   10149   54789
# 96                      538                     382    1085
# 97                      619                     447     994
# 98                     1650                    1193    2163
# 99                     1721                    1261    2278
#
#    Aggravated assault Property crime Burglary Larceny-theft  \
# 0                4099          65610    10286         48898
# 1                4579          64664    10045         47512
# 2                 931          24361     4694         18853
# 3                 950          21912     4003         17134
# 4               18974         114547    21826         84676
# ..                ...            ...      ...           ...
# 95             104375        1002070   188304        637010
# 96               1878          45389     6810         33140
# 97               2769          42753     6017         31082
# 98               6757         119752    18541         90514
# 99               6718         121345    16866         91286
#
#    Motor vehicle theft
# 0                 6426
# 1                 7107
# 2                  814
# 3                  775
# 4                 8045
# ..                 ...
# 95              176756
# 96                5439
# 97                5654
# 98               10697
# 99               13193
#
# [100 rows x 15 columns]

# %%
# from google.colab import files
# files.download("fbi.csv")
# Assuming your cleaned data is in a pandas DataFrame called 'fbi_clean'
fbi.to_csv('fbi_clean.csv', index=False)  # Save without index column

# %%
count_row = fbi.shape[0]
fbi.shape
# Out:
# (102, 15)
